# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
atmos = np.load("current_atmos_old.npz", allow_pickle=True)

# %%
atmos["T"].shape
# Out:
# (768, 768, 256)

# %%
plt.imshow(atmos["vx"][:,:,-50].T/1E3, origin='lower', cmap='bwr',vmin=-5, vmax=5)
plt.colorbar()
